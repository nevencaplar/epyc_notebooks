# %%
from lsstseries import Ensemble
from lsstseries.analysis.structurefunction2 import calc_sf2
from lsstseries.analysis.stetsonj import calc_stetson_J
import numpy as np
import hipscat
import dask.dataframe as dd
import pandas as pd
from dask.distributed import Client
import multiprocessing;multiprocessing.cpu_count()
# Out:
# 96

# %%
ens = Ensemble()
ens = ens.from_parquet("ztf_testdata/*.parquet",
                      id_col="ps1_objid",
                      time_col="mjd",
                      flux_col="mag",
                      err_col="magerr")

ens.dropna(1).prune(100)
# Out:
# /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35172 instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/dask/backends.py:133, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     132 try:
# --> 133     return func(*args, **kwargs)
#     134 except Exception as e:
#
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/dask/dataframe/io/parquet/core.py:541, in read_parquet(path, columns, filters, categories, index, storage_options, engine, use_nullable_dtypes, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, **kwargs)
#     539     blocksize = None
# --> 541 read_metadata_result = engine.read_metadata(
#     542     fs,
#     543     paths,
#     544     categories=categories,
#     545     index=index,
#     546     use_nullable_dtypes=use_nullable_dtypes,
#     547     gather_statistics=calculate_divisions,
#     548     filters=filters,
#     549     split_row_groups=split_row_groups,
#     550     blocksize=blocksize,
#     551     aggregate_files=aggregate_files,
#     552     ignore_metadata_file=ignore_metadata_file,
#     553     metadata_task_size=metadata_task_size,
#     554     parquet_file_extension=parquet_file_extension,
#     555     dataset=dataset_options,
#     556     read=read_options,
#     557     **other_options,
#     558 )
#     560 # In the future, we may want to give the engine the
#     561 # option to return a dedicated element for `common_kwargs`.
#     562 # However, to avoid breaking the API, we just embed this
#     563 # data in the first element of `parts` for now.
#     564 # The logic below is inteded to handle backward and forward
#     565 # compatibility with a user-defined engine.
#
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/dask/dataframe/io/parquet/arrow.py:446, in ArrowDatasetEngine.read_metadata(cls, fs, paths, categories, index, use_nullable_dtypes, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, **kwargs)
#     445 # Stage 2: Generate output `meta`
# --> 446 meta = cls._create_dd_meta(
#     447     dataset_info, use_nullable_dtypes=use_nullable_dtypes
#     448 )
#     450 # Stage 3: Generate parts and stats
#
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/dask/dataframe/io/parquet/arrow.py:1166, in ArrowDatasetEngine._create_dd_meta(cls, dataset_info, use_nullable_dtypes)
#    1165 if index_cols and index_cols != [None]:
# -> 1166     meta.set_index(index_cols, inplace=True)
#    1168 # Ensure that there is no overlap between partition columns
#    1169 # and explicit column storage
#
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/pandas/core/frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
#
# KeyError: "None of ['ps1_objid'] are in the columns"
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 ens = Ensemble()
# ----> 2 ens = ens.from_parquet("ztf_testdata/*.parquet",
#       3                       id_col="ps1_objid",
#       4                       time_col="mjd",
#       5                       flux_col="mag",
#       6                       err_col="magerr")
#       8 ens.dropna(1).prune(100)
#
# File /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:289, in Ensemble.from_parquet(self, file, id_col, time_col, flux_col, err_col, band_col, additional_cols, npartitions, partition_size)
#     286     columns = [self._time_col, self._flux_col, self._err_col, self._band_col]
#     288 # Read in a parquet file
# --> 289 self._data = dd.read_parquet(
#     290     file, index=self._id_col, columns=columns, split_row_groups=True
#     291 )
#     293 if npartitions and npartitions > 1:
#     294     self._data = self._data.repartition(npartitions=npartitions)
#
# File /astro/users/brantd/.conda/envs/py310/lib/python3.10/site-packages/dask/backends.py:135, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     133     return func(*args, **kwargs)
#     134 except Exception as e:
# --> 135     raise type(e)(
#     136         f"An error occurred while calling the {funcname(func)} "
#     137         f"method registered to the {self.backend} backend.\n"
#     138         f"Original Message: {e}"
#     139     ) from e
#
# KeyError: 'An error occurred while calling the read_parquet method registered to the pandas backend.\nOriginal Message: "None of [\'ps1_objid\'] are in the columns"'

# %%
ens.client_info()
# Out:
# <Client: 'tcp://127.0.0.1:34400' processes=12 threads=96, memory=0.98 TiB>

# %%
res = ens.batch(calc_stetson_J, band_to_calc='g')
# Out:
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(

# %%
res = ens.batch(calc_sf2, sthresh=50, band_to_calc=['g','r'])
# Out:
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col, group_keys=False).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col, group_keys=False).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(
# /data/epyc/users/brantd/lsstseries/src/lsstseries/ensemble.py:211: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   batch = self._data.map_partitions(lambda x: x.groupby(id_col).apply(

# %%
res.to_csv("out.csv")

# %%
len(res['lc_id'].unique())
# Out:
# 203192

# %%
res
# Out:
# ps1_objid
# 74420597561988984      {'g': 0.6647264}
# 74420599952839167     {'g': 0.29402572}
# 74420606343319964      {'g': 0.3331358}
# 74420664289979622      {'g': 1.0316911}
# 74420666002478050    {'g': -0.28180474}
#                             ...
# 84590674993150565     {'g': 0.10141596}
# 84590675195062274      {'g': 0.7435742}
# 84590675217217666    {'g': -0.12472639}
# 84600675154817484    {'g': -0.09470266}
# 84610675136421586    {'g': -0.11108887}
# Name: ps1_objid, Length: 203192, dtype: object
